# %%
import pandas as pd

# %%
dataset = pd.read_excel("inventory.xlsx")

# %%
dataset
# Out:
#        Jahr Proben Nr Probenbezeichnung                 Probenart  \
# 0      2009   4000/09     Tr - 08 / 1-1                       Erz
# 1      2009   4001/09     Tr - 08 / 1-2                       Erz
# 2      2009   4002/09    Tr - 08 / 2-3a                       Erz
# 3      2009   4003/09    Tr - 08 / 2-3b                       Erz
# 4      2009   4004/09    Tr - 08 / 2-4a                       Erz
# ...     ...       ...               ...                       ...
# 13135  2019   4837/19            153/23                       NaN
# 13136  2019   4838/19            154/23                       NaN
# 13137  2019   4839/19            155/19                       NaN
# 13138  2019   4840/19              8074  Residue of a mining tool
# 13139  2019   4841/19              8074  Residue of a mining tool
#
#                  Herkunft        Auftraggeber-FD  Projektename Projekt Nr  \
# 0                  Türkei                 Yalcin           NaN        NaN
# ...
